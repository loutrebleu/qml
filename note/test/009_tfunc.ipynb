# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("../..")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from qml.db import target as xtarget

# %%
fgen = xtarget.PolynominalTargetFunctionGenerator(4)
func = fgen.generate()

xs = np.linspace(-1, 1, 101)
ys = func(xs)
plt.scatter(xs, ys)

# %%
fgen = xtarget.PolynominalTargetFunctionGenerator(5)
func = fgen.generate()

xs = np.linspace(-1, 1, 101)
ys = func(xs)
plt.scatter(xs, ys)
