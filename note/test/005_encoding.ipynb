# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("../..")

# %%
from qiskit import QuantumCircuit

# %%
from qml.model.encoding import EncodingUnitManager

# %%
nx = 1
nq = 3

unit = EncodingUnitManager.AngleEncoding(nx, nq, repeat=True)

# %%
qc = QuantumCircuit(nq, 1)
unit.apply_to_qc(qc)
qc.draw("mpl")
